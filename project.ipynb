# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# All the data columns names:

# %%
df.columns
# Out:
# Index(['Position', 'Team', 'Games Played', 'Win', 'Draw', 'Loss', 'Goals For',
#        'Goals Against', 'Goal Difference', 'Points'],
#       dtype='object')

# %% [markdown]
# Import data on the top of the list:

# %%
df.head(4)
# Out:
#    Position     Team  Games Played  Win  Draw  Loss  Goals For  Goals Against  \
# 0         1   France           7.0  6.0   1.0   0.0       14.0            6.0
# 1         2  Croatia           7.0  4.0   2.0   1.0       14.0            9.0
# 2         3  Belgium           7.0  NaN   NaN   NaN        NaN            NaN
# 3         4  England           7.0  3.0   1.0   3.0       12.0            8.0
#
#   Goal Difference  Points
# 0               8    19.0
# 1               5    14.0
# 2             NaN     NaN
# 3               4    10.0

# %% [markdown]
# Shape of dataframe:

# %%
df.shape
# Out:
# (33, 10)

# %% [markdown]
# Use to find lower data:

# %%
df.tail(2)
# Out:
#     Position    Team  Games Played  Win  Draw  Loss  Goals For  Goals Against  \
# 31        32  Panama           3.0  0.0   0.0   3.0        2.0           11.0
# 32        33   india           NaN  NaN   NaN   NaN        NaN            NaN
#
#    Goal Difference  Points
# 31              −9     0.0
# 32             NaN     NaN

# %% [markdown]
# Random sample of rows and columns:

# %%
df.sample(3)
# Out:
#     Position     Team  Games Played  Win  Draw  Loss  Goals For  \
# 11        12    Spain           4.0  1.0   3.0   0.0        7.0
# 3          4  England           7.0  3.0   1.0   3.0       12.0
# 19        20  Nigeria           3.0  1.0   0.0   2.0        3.0
#
#     Goals Against Goal Difference  Points
# 11            6.0               1     6.0
# 3             8.0               4    10.0
# 19            4.0              −1     3.0

# %%
df.columns
# Out:
# Index(['Position', 'Team', 'Games Played', 'Win', 'Draw', 'Loss', 'Goals For',
#        'Goals Against', 'Goal Difference', 'Points'],
#       dtype='object')

# %%
df.rename(columns={"Team":"Country"},inplace=True)
df
# Out:
#     Position       Country  Games Played  Win  Draw  Loss  Goals For  \
# 0          1        France           7.0  6.0   1.0   0.0       14.0
# 1          2       Croatia           7.0  4.0   2.0   1.0       14.0
# 2          3       Belgium           7.0  NaN   NaN   NaN        NaN
# 3          4       England           7.0  3.0   1.0   3.0       12.0
# 4          5       Uruguay           5.0  4.0   0.0   1.0        7.0
# 5          6        Brazil           5.0  3.0   1.0   1.0        8.0
# 6          7        Sweden           5.0  3.0   0.0   2.0        6.0
# 7          8        Russia           5.0  2.0   2.0   1.0       11.0
# 8          9      Colombia           4.0  2.0   1.0   1.0        6.0
# 9         10        Mexico           4.0  2.0   0.0   2.0        3.0
# 10        11       Denmark           4.0  1.0   3.0   0.0        3.0
# 11        12         Spain           4.0  1.0   3.0   0.0        7.0
# 12        13      Portugal           4.0  NaN   NaN   NaN        NaN
# ...

# %% [markdown]
# Data cleaning:

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Position       Country  Games Played  Win  Draw  Loss  Goals For  \
# 0          1        France           7.0  6.0   1.0   0.0       14.0
# 1          2       Croatia           7.0  4.0   2.0   1.0       14.0
# 3          4       England           7.0  3.0   1.0   3.0       12.0
# 4          5       Uruguay           5.0  4.0   0.0   1.0        7.0
# 5          6        Brazil           5.0  3.0   1.0   1.0        8.0
# 6          7        Sweden           5.0  3.0   0.0   2.0        6.0
# 7          8        Russia           5.0  2.0   2.0   1.0       11.0
# 8          9      Colombia           4.0  2.0   1.0   1.0        6.0
# 9         10        Mexico           4.0  2.0   0.0   2.0        3.0
# 10        11       Denmark           4.0  1.0   3.0   0.0        3.0
# 11        12         Spain           4.0  1.0   3.0   0.0        7.0
# 13        14   Switzerland           4.0  1.0   2.0   1.0        5.0
# 14        15     Argentina           4.0  1.0   1.0   2.0        6.0
# ...

# %%
df.isnull().sum()
# Out:
# Position           0
# Country            0
# Games Played       0
# Win                0
# Draw               0
# Loss               0
# Goals For          0
# Goals Against      0
# Goal Difference    0
# Points             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Position           0
# Country            0
# Games Played       0
# Win                0
# Draw               0
# Loss               0
# Goals For          0
# Goals Against      0
# Goal Difference    0
# Points             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 31
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Position         30 non-null     int64
#  1   Country          30 non-null     object
#  2   Games Played     30 non-null     float64
#  3   Win              30 non-null     float64
#  4   Draw             30 non-null     float64
#  5   Loss             30 non-null     float64
#  6   Goals For        30 non-null     float64
#  7   Goals Against    30 non-null     float64
#  8   Goal Difference  30 non-null     object
#  9   Points           30 non-null     float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.6+ KB

# %%
df = df.describe(include="all")

# %%
df.loc[["top","mean"]]
# Out:
#        Position Country  Games Played       Win  Draw      Loss  Goals For  \
# top         NaN  France           NaN       NaN   NaN       NaN        NaN
# mean  17.066667     NaN           3.9  1.466667   0.8  1.633333        4.9
#
#       Goals Against Goal Difference  Points
# top             NaN              −3     NaN
# mean       5.233333             NaN     5.2

# %%
df.iloc[[0,1,3]]
# Out:
#         Position Country  Games Played   Win  Draw  Loss  Goals For  \
# count       30.0      30          30.0  30.0  30.0  30.0       30.0
# unique       NaN      30           NaN   NaN   NaN   NaN        NaN
# freq         NaN       1           NaN   NaN   NaN   NaN        NaN
#
#         Goals Against Goal Difference  Points
# count            30.0              30    30.0
# unique            NaN              13     NaN
# freq              NaN               7     NaN

# %%
df[["Position", "Points"]]
# Out:
#          Position    Points
# count   30.000000  30.00000
# unique        NaN       NaN
# top           NaN       NaN
# freq          NaN       NaN
# mean    17.066667   5.20000
# std      9.328981   4.38178
# min      1.000000   0.00000
# 25%      9.250000   3.00000
# 50%     17.500000   4.00000
# 75%     24.750000   6.75000
# max     32.000000  19.00000

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
df[["Position","Games Played"]]
# Out:
#          Position  Games Played
# count   30.000000     30.000000
# unique        NaN           NaN
# top           NaN           NaN
# freq          NaN           NaN
# mean    17.066667      3.900000
# std      9.328981      1.268994
# min      1.000000      3.000000
# 25%      9.250000      3.000000
# 50%     17.500000      3.000000
# 75%     24.750000      4.000000
# max     32.000000      7.000000

# %%
df.columns
# Out:
# Index(['Position', 'Country', 'Games Played', 'Win', 'Draw', 'Loss',
#        'Goals For', 'Goals Against', 'Goal Difference', 'Points'],
#       dtype='object')

# %% [markdown]
# Find mean:

# %%
df["Points"].mean()
# Out:
# 9.041472557505166

# %% [markdown]
# Finding mode:

# %%
df["Points"].mode()
# Out:
# 0     0.00000
# 1     3.00000
# 2     4.00000
# 3     4.38178
# 4     5.20000
# 5     6.75000
# 6    19.00000
# 7    30.00000
# Name: Points, dtype: float64

# %% [markdown]
# Finding median:

# %%
df["Points"].median()
# Out:
# 4.790890230020664

# %% [markdown]
# Finding value counts:

# %%
df["Points"].value_counts()
# Out:
# Points
# 30.00000    1
# 5.20000     1
# 4.38178     1
# 0.00000     1
# 3.00000     1
# 4.00000     1
# 6.75000     1
# 19.00000    1
# Name: count, dtype: int64

# %% [markdown]
# Plotting value count graph:

# %%
df["Points"].value_counts().plot(kind="bar",title="Company",color="green")
# Out:
# <Axes: title={'center': 'Company'}, xlabel='Points'>

# %%
df["Points"].value_counts().plot(kind="pie",title="Company",color="green")
# Out:
# <Axes: title={'center': 'Company'}, ylabel='count'>

# %%
df["Points"].value_counts().plot(kind="hist",title="Company",color="green")
# Out:
# <Axes: title={'center': 'Company'}, ylabel='Frequency'>

# %%
df["Points"].value_counts().plot(kind="line",title="Company",color="green")
# Out:
# <Axes: title={'center': 'Company'}, xlabel='Points'>

# %%
pd.isnull(df)
# Out:
#         Position  Country  Games Played    Win   Draw   Loss  Goals For  \
# count      False    False         False  False  False  False      False
# unique      True    False          True   True   True   True       True
# top         True    False          True   True   True   True       True
# freq        True    False          True   True   True   True       True
# mean       False     True         False  False  False  False      False
# std        False     True         False  False  False  False      False
# min        False     True         False  False  False  False      False
# 25%        False     True         False  False  False  False      False
# 50%        False     True         False  False  False  False      False
# 75%        False     True         False  False  False  False      False
# max        False     True         False  False  False  False      False
#
#         Goals Against  Goal Difference  Points
# count           False            False   False
# ...

# %%
df.isnull().sum()
# Out:
# Position           3
# Country            7
# Games Played       3
# Win                3
# Draw               3
# Loss               3
# Goals For          3
# Goals Against      3
# Goal Difference    7
# Points             3
# dtype: int64

# %%
df[df["Points"].isnull()]
# Out:
#         Position Country  Games Played  Win  Draw  Loss  Goals For  \
# unique       NaN      30           NaN  NaN   NaN   NaN        NaN
# top          NaN  France           NaN  NaN   NaN   NaN        NaN
# freq         NaN       1           NaN  NaN   NaN   NaN        NaN
#
#         Goals Against Goal Difference  Points
# unique            NaN              13     NaN
# top               NaN              −3     NaN
# freq              NaN               7     NaN

# %%
df["Goal Difference"] = df["Points"].fillna(df["Points"].mean())
df
# Out:
#          Position Country  Games Played        Win       Draw       Loss  \
# count   30.000000      30     30.000000  30.000000  30.000000  30.000000
# unique        NaN      30           NaN        NaN        NaN        NaN
# top           NaN  France           NaN        NaN        NaN        NaN
# freq          NaN       1           NaN        NaN        NaN        NaN
# mean    17.066667     NaN      3.900000   1.466667   0.800000   1.633333
# std      9.328981     NaN      1.268994   1.407696   0.886683   0.808717
# min      1.000000     NaN      3.000000   0.000000   0.000000   0.000000
# 25%      9.250000     NaN      3.000000   1.000000   0.000000   1.000000
# 50%     17.500000     NaN      3.000000   1.000000   1.000000   2.000000
# 75%     24.750000     NaN      4.000000   2.000000   1.000000   2.000000
# max     32.000000     NaN      7.000000   6.000000   3.000000   3.000000
#
#         Goals For  Goals Against  Goal Difference    Points
# ...

# %%
df[df["Points"].isnull()]
# Out:
#         Position Country  Games Played  Win  Draw  Loss  Goals For  \
# unique       NaN      30           NaN  NaN   NaN   NaN        NaN
# top          NaN  France           NaN  NaN   NaN   NaN        NaN
# freq         NaN       1           NaN  NaN   NaN   NaN        NaN
#
#         Goals Against  Goal Difference  Points
# unique            NaN         9.041473     NaN
# top               NaN         9.041473     NaN
# freq              NaN         9.041473     NaN

# %%
df.groupby("Points").describe()
# Out:
#          Position                                                             \
#             count       mean std        min        25%        50%        75%
# Points
# 0.00000       1.0   1.000000 NaN   1.000000   1.000000   1.000000   1.000000
# 3.00000       1.0   9.250000 NaN   9.250000   9.250000   9.250000   9.250000
# 4.00000       1.0  17.500000 NaN  17.500000  17.500000  17.500000  17.500000
# 4.38178       1.0   9.328981 NaN   9.328981   9.328981   9.328981   9.328981
# 5.20000       1.0  17.066667 NaN  17.066667  17.066667  17.066667  17.066667
# 6.75000       1.0  24.750000 NaN  24.750000  24.750000  24.750000  24.750000
# 19.00000      1.0  32.000000 NaN  32.000000  32.000000  32.000000  32.000000
# 30.00000      1.0  30.000000 NaN  30.000000  30.000000  30.000000  30.000000
#
#                     Games Played                                       \
#                 max        count       mean std        min        25%
# Points
# ...

# %%
df.to_csv("data2.csv")
